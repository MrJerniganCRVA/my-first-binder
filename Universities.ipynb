# %% [markdown]
# # Wikipedia Collection script for R1/R2 Universities
#
# ## Setup
#
# Grab and install the wikipedia api library.  This only needs ot be run once ever.

# %%
# %pip install wikipedia # run once then comment this out
# Out:
# Requirement already satisfied: wikipedia in /Users/pbutler/anaconda3/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /Users/pbutler/anaconda3/lib/python3.11/site-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/pbutler/anaconda3/lib/python3.11/site-packages (from wikipedia) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pbutler/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pbutler/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pbutler/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pbutler/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/pbutler/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->wikipedia) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Imports

# %%
import wikipedia
import pandas as pd

# %% [markdown]
# ## Code
#
# Get a list of links from the page "List of research univiserties in the United States"

# %%
list_page = wikipedia.page("List_of_research_universities_in_the_United_States")
list_page.links[:10]
# Out:
# ['Aggregate data',
#  'Air Force Institute of Technology',
#  'Alabama',
#  'Alaska',
#  'Albany, New York',
#  'Albert Einstein College of Medicine',
#  'Albuquerque',
#  'American Council on Education',
#  'American University',
#  'Ames, Iowa']

# %% [markdown]
# ### Links pertaining to R1/R2 Universities
#
# The list contains things other than universities... rather than grab a bunch of extra links we'll go to each page, look at the possible categories and make at least one contains the stemmed word for `univsersit` at the beginning (there's no 'university' category exactly but plenty of categories that start with "Universit").  This still isn't perfect but should be good enough for the assignment.

# %%
dataset = []
for college in list_page.links:
    try:
        print(college, end="")
        page = wikipedia.page(college)
        if any(c.lower().startswith("universit") for c in page.categories):
            dataset += [{"college": college,
                         "content": page.content,
                         "nrefs": len(page.references),
                         "nlinks": len(page.links),
                         #"lat": round(page.coordinates[0], 10), # nice idea but not defined for all pages
                         #"long": round(page.coordinates[1], 10)
                        }]
            print(" |  okay")
        else:
            print(" |  other")
    except wikipedia.PageError:
        print(" |  error (page)")
    except wikipedia.DisambiguationError:
        print(" |  error (double)")
dataset = pd.DataFrame(dataset)
# Out:
# Aggregate data |  other
# Air Force Institute of Technology |  okay
# Alabama |  other
# Alaska |  other
# Albany, New York |  other
# Albert Einstein College of Medicine |  okay
# Albuquerque |  other
# American Council on Education |  other
# American University |  okay
# Ames, Iowa |  other
# Amherst, Massachusetts |  other
# Ann Arbor, Michigan |  other
# Arizona |  other
# Arizona State University |  okay
# Arkansas |  other
# Arkansas State University |  okay
# Arlington, Texas |  other
# Association of American Universities |  other
# Athens, Georgia |  other
# Athens, Ohio |  other
# Atlanta |  other
# Auburn, Alabama |  other
# Auburn University |  okay
# Augusta University |  okay
# Austin, Texas |  other
# Azusa Pacific University |  okay
# Ball State University |  okay
# Baltimore |  other
# Baton Rouge |  other
# Baylor College of Medicine |  okay
# Baylor University |  okay
# Berkeley, California |  other
# Binghamton University |  okay
# Birmingham, Alabama |  other
# Blacksburg, Virginia |  other
# Bloomington, Indiana |  other
# Boise State University |  okay
# Boston |  other
# Boston College |  okay
# Boston University |  okay
# Boulder, Colorado |  other
# Bowling Green State University |  okay
# Bozeman, Montana |  other
# Brandeis University |  okay
# Brigham Young University |  okay
# Brown University |  okay
# Buffalo, New York |  other
# CUNY City College |  okay
# California |  other
# California Institute of Technology |  okay
# California State University, East Bay |  okay
# California State University, Fresno |  okay
# California State University, Fullerton |  okay
# California State University, Long Beach |  okay
# California State University, San Bernardino |  okay
# Cambridge, Massachusetts |  other
# Carnegie Classification of Institutions of Higher Education |  other
# Carnegie Mellon University |  okay
# Case Western Reserve University |  okay
# Catholic University of America |  okay
# Center for Measuring University Performance |  okay
# Center for Postsecondary Research |  error (page)
# Central Michigan University |  okay
# Champaign, Illinois |  other
# Chapel Hill, North Carolina |  other
# Chapman University |  okay
# Charlottesville, Virginia |  other
# Chestnut Hill, Massachusetts |  other
# Chicago |  other
# Cincinnati |  other
# Cincinnati, Ohio |  other
# Claremont Graduate University |  okay
# Clark Atlanta University |  okay
# Clark University |  okay
# Clarkson University |  okay
# Clemson, South Carolina |  other
# Clemson University |  error (page)
# Cleveland |  other
# Cleveland State University |  okay
# College Park, Maryland |  other
# College Station, Texas |  other
# College of William and Mary |  okay
# Colorado |  other
# Colorado School of Mines |  okay
# Colorado State University |  okay
# Columbia, Missouri |  other
# Columbia, South Carolina |  other
# Columbia University |  okay
# Columbus, Ohio |  other
# Connecticut |  other
# Coral Gables, Florida |  other
# Cornell University |  okay
# Corvallis, Oregon |  other
# Creighton University |  okay
# Dartmouth College |  okay
# Davis, California |  other
# DePaul University |  okay
# Delaware |  other
# Denton, Texas |  other
# Denver |  error (page)
# Detroit |  other
# Doctorate |  other
# Drexel University |  okay
# Duke University |  okay
# Duquesne University |  okay
# Durham, New Hampshire |  other
# Durham, North Carolina |  other
# East Carolina University |  okay
# East Lansing, Michigan |  other
# East Tennessee State University |  okay
# Eastern Michigan University |  error (page)
# Eastern Virginia Medical School |  okay
# El Paso, Texas |  other
# Emory University |  okay
# Eugene, Oregon |  other
# Evanston, Illinois |  other
# Fairfax, Virginia |  other
# Fargo, North Dakota |  other
# Fayetteville, Arkansas |  other
# Florida |  other
# Florida Agricultural and Mechanical University |  okay
# Florida Atlantic University |  okay
# Florida Institute of Technology |  okay
# Florida International University |  okay
# Florida State University |  okay
# Fordham University |  okay
# Fort Collins, Colorado |  other
# Gainesville, Florida |  other
# George Mason University |  okay
# George Washington University |  other
# Georgetown University |  error (page)
# Georgia (U.S. state) |  other
# Georgia Institute of Technology |  okay
# Georgia Southern University |  okay
# Georgia State University |  okay
# Golden, Colorado |  other
# Graduate Center, CUNY |  okay
# Hanover, New Hampshire |  other
# Harvard University |  okay
# Hattiesburg, Mississippi |  other
# Hawaii |  other
# Honolulu |  other
# Houston |  other
# Howard University |  okay
# Huntsville, Alabama |  other
# Icahn School of Medicine at Mount Sinai |  okay
# Idaho |  other
# Idaho State University |  okay
# Illinois |  other
# Illinois Institute of Technology |  okay
# Illinois State University |  okay
# Indiana
# /Users/pbutler/anaconda3/lib/python3.11/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /Users/pbutler/anaconda3/lib/python3.11/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
#  |  error (double)
# Indiana University Bloomington |  okay
# Indiana University of Pennsylvania |  okay
# Indiana University – Purdue University Indianapolis |  okay
# Iowa |  other
# Iowa City |  other
# Iowa State University |  error (page)
# Irvine, California |  other
# Ithaca, New York |  other
# Jackson State University |  okay
# James Madison University |  okay
# Johns Hopkins University |  okay
# Kansas |  other
# Kansas State University |  okay
# Kennesaw State University |  okay
# Kent, Ohio |  other
# Kent State University |  okay
# Kentucky |  other
# Knoxville, Tennessee |  other
# LIU Post |  error (page)
# Lafayette, Louisiana |  other
# Las Vegas |  other
# University of Missouri–St. Louis |  okay
# University of Montana |  okay
# University of Nebraska Medical Center |  okay
# University of Nebraska at Omaha |  okay
# University of Nebraska–Lincoln |  okay
# University of Nevada, Las Vegas |  okay
# University of Nevada, Reno |  okay
# University of New England (United States) |  okay
# University of New Hampshire |  okay
# University of New Mexico |  okay
# University of New Orleans |  okay
# University of North Carolina Wilmington |  okay
# University of North Carolina at Chapel Hill |  okay
# University of North Carolina at Charlotte |  okay
# University of North Carolina at Greensboro |  okay
# University of North Dakota |  okay
# University of North Florida |  okay
# University of North Texas |  okay
# University of Notre Dame |  okay
# University of Oklahoma |  okay
# University of Oklahoma Health Sciences Center |  okay
# University of Oregon |  okay
# University of Pennsylvania |  okay
# University of Pittsburgh |  okay
# University of Puerto Rico at Rio Piedras |  okay
# University of Puerto Rico at Río Piedras |  okay
# University of Rhode Island |  okay
# University of Rochester |  okay
# University of San Diego |  okay
# University of South Alabama |  okay
# University of South Carolina |  okay
# University of South Dakota |  okay
# University of South Florida |  okay
# University of Southern California |  okay
# University of Southern Mississippi |  okay
# University of Tennessee |  okay
# University of Tennessee Health Science Center |  okay
# University of Texas Health Science Center at Houston |  okay
# University of Texas Health Science Center at San Antonio |  okay
# University of Texas Medical Branch |  okay
# University of Texas Rio Grande Valley |  okay
# University of Texas Southwestern Medical Center |  okay
# University of Texas at Arlington |  okay
# University of Texas at Austin |  okay
# University of Texas at Dallas |  okay
# University of Texas at El Paso |  okay
# University of Texas at San Antonio |  okay
# University of Texas at Tyler |  okay
# University of Toledo |  okay
# University of Tulsa |  okay
# University of Utah |  error (page)
# University of Vermont |  okay
# University of Virginia |  okay
# University of Washington |  okay
# University of Wisconsin–Madison |  okay
# University of Wisconsin–Milwaukee |  okay
# University of Wyoming |  error (page)
# Utah |  other
# Utah State University |  okay
# Vanderbilt University |  okay
# Vermont |  other
# Vestal, New York |  other
# Villanova University |  okay
# Virginia |  other
# Virginia Commonwealth University |  okay
# Virginia Tech |  okay
# Waco, Texas |  other
# Wake Forest University |  okay
# Waltham, Massachusetts |  other
# Washington, D.C. |  error (page)
# Washington (state) |  other
# Washington State University |  okay
# Washington University in St. Louis |  okay
# Wayback Machine |  other
# Wayne State University |  okay
# Weill Cornell Medicine |  okay
# West Chester University of Pennsylvania |  okay
# West Lafayette, Indiana |  other
# West Virginia |  other
# West Virginia University |  okay
# Western Michigan University |  okay
# Wichita State University |  okay
# Wisconsin |  other
# Worcester Polytechnic Institute |  okay
# Wright State University |  okay
# Wyoming |  other
# Yale University |  okay

# %% [markdown]
# ### Verify
#
# Double check that the articles collect are mostly universities.

# %%
dataset.head()
# Out:
#                                college  \
# 0    Air Force Institute of Technology
# 1  Albert Einstein College of Medicine
# 2                  American University
# 3             Arizona State University
# 4            Arkansas State University
#
#                                              content  nrefs  nlinks
# 0  The Air Force Institute of Technology (AFIT) i...    142     253
# 1  The Albert Einstein College of Medicine is a p...     88     234
# 2  The American University (AU or American) is a ...    148     423
# 3  Arizona State University (Arizona State or ASU...    515     880
# 4  Arkansas State University (A-State or ASU) is ...    109     281

# %% [markdown]
# ### Save

# %%
dataset.to_json("universities.json")

# %% [markdown]
# ### Open (for your homework)

# %%
import pandas as pd
